# %% [markdown]
# # 00COVID19-V6 South Korea

# %% [markdown]
# # Introduction

# %% [markdown]
# As the lead data scientist for the government of the Republic of Lithuania, I have the task to prepare the nation for a possible next wave of the COVID-19 pandemic. Since South Korea was one of the more successful nations in the fight against COVID-19, I decided to analyze the available COVID-19 data from this country to learn about their successes and failures. I will report my findings to appropriate government officials in Lithuania.
#
# In this report, I will illustrate how a population's day-to-day actions have an enormous impact in controlling a pandemic. I will show how a small group of people, by their actions, can change the course of a pandemic for the worst. Specifically, I will focus on one such group, the members of the Shincheonji Church, with branches throughout South Korea. Many of the members of this small group disregarded government policies and scientific principles and were linked to about half of the COVID-19 infections in South Korea during the period of my analysis, January to June 2020. I will also show the effect of government policies, how differences in age and gender can affect who gets infected by COVID-19 and possibly who dies.
#
# Although South Korea's 52 million population is over 16 times larger than Lithuania's 3 million, and although what worked in one country may not work in another, there are certainly parallels that can be drawn and in this report I seek to do that.
#
# I will focus my report specifically on the nine provinces and the eight special administrative divisions of South Korea. My report will not focus on smaller geographical units such as cities, townships or villages.
#
# With one exception, this report concerns itself with data on confirmed cases of COVID-19. Looking at deceased data is beyond the scope of this report. There are many reasons why a person would die after being infected by COVID-19 and I do not have enough expertise to adequately analyze this data. So, except in one case as it relates to gender, I stayed away from such analysis.

# %% [markdown]
# # Goal

# %% [markdown]
# The goal of this analysis is to present my findings of South Korean COVID-19 data and provide the government of the Republic of Lithuania with recommendations on how to prepare for a possible next wave of COVID-19 or similar pandemic.

# %% [markdown]
# # Hypothesis

# %% [markdown]
# To effectively fight a pandemic it is essential for the population to follow guidelines based on scientific principle known at the time.

# %% [markdown]
# # Technical Requirements from Turing College

# %% [markdown]
# 1. Identify opportunities for data analysis
# 2. Perform EDA
# 3. Work with data from Kaggle
# 4. Visualize data with Matplotlib & Seaborn
# 5. Read data, perform queries, and filter data using Pandas

# %% [markdown]
# # Datasets

# %% [markdown]
# I utilized the following datasets which contain COVID-19 data in South Korea from January to June 2020:
#
# **1. Age:** Confirmed and deceased cases based on age groups <br>
# **2. Gender:** Confirmed and deceased cases based on gender <br>
# **3. Province:** Confirmed and deceased cases based on province <br>
# **4. Patient:** Confirmed and deceased cases based on age, gender, method of infection, province and city <br>
# **5. Case:** Confirmed cases based on method of infection, province, city, and specific location <br>
# **6. Population:** Count and ratio of academic organizations, nursing homes and elderly population <br>
# **7. Test:** Number of tests and number of negative and positive results <br>
# **8. Policy:** Government actions and policies by date

# %% [markdown]
# # South Korea

# %% [markdown]
# South Korea is a country in East Asia with a population of 52 million. It is bordered in the north by North Korea, in the west by the Yellow Sea, and in the east by the Sea of Japan. In the south, the country is bordered by Japan and the East China Sea. Roughly half of the South Korean population live in Seoul, which is the fifth largest city in the world by population. Other major cities in South Korea include Incheon, Busan, and Daegu. One of the focuses on this report, is on the metropolitan city, Daegu, which was the origin of the first major outbreak of COVID-19 in South Korea and one of the worst affected.
#
# The closest air distance between South Korean and China (the origin of the COVID-19 pandemic) is between Xi'an Xianyang International Airport in China and Cheongju International Airport in South Korea. This distance is approximately 2,000 km by air. This corresponds to a flight time of approximately 3 hours. The first case of COVID-19 infection is believed to have been brought to South Korea by a traveler from China, although not from these two airports
#
# South Korea is divided into 9 Provinces and 8 Special Admininstrative Divisions.
#
# **Provinces in South Korea:**
# 1. **North Chungcheong** (Chungcheongbuk-do)
# 2. **South Chungcheong** (Chungcheongnam-do)
# 3. **Gangwon** (Gangwon-do)
# 4. **Gyeonggi** (Gyeonggi-do)
# 5. **North Gyeongsang** (Gyeongsangbuk-do)
# 6. **South Gyeongsang** (Gyeongsangnam-do)
# 7. **North Jeolla** (Jeollabuk-do)
# 8. **South Jeolla** (Jeollanam-do)
# 9. **Jeju** (Special Self-Governing Province)
#
#
# **Special Administrtative Divisions in South Korea:**
# 1. **Seoul** (Special City) <br>
# 2. **Sejong** (Special Self-governing City) <br>
# 3. **Busan** (Metropolitan City) <br>
# 4. **Daegu** (Metropolitan City) <br>
# 5. **Incheon** (Metropolitan City) <br>
# 6. **Gwangju** (Metropolitan City) <br>
# 7. **Daejeon** (Metropolitan City) <br>
# 8. **Ulsan** (Metropolitan City) <br>
#
# The map below provides a picture of South Korean regions indicated above.

# %% [markdown]
# ![South%20Korea.jpg](attachment:South%20Korea.jpg)

# %% [markdown]
# # COVID-19 in South Korea

# %% [markdown]
# ## What is COVID-19?

# %% [markdown]
# Coronavirus disease (COVID-19) is an infectious disease caused by the SARS-CoV-2 virus.
#
# Most people infected with the virus will experience mild to moderate respiratory illness and recover without requiring special treatment. However, some will become seriously ill and require medical attention. Older people and those with underlying medical conditions like cardiovascular disease, diabetes, chronic respiratory disease, or cancer are more likely to develop serious illness. Anyone can get sick with COVID-19 and become seriously ill or die at any age.
#
# The virus can spread from an infected person’s mouth or nose in small liquid particles when they cough, sneeze, speak, sing or breathe. These particles range from larger respiratory droplets to smaller aerosols.
#
# Outside of China, South Korea was one of the most affected countries with COVID-19 infections.
#
# *World Health Organization* <br>
# https://www.who.int/health-topics/coronavirus

# %% [markdown]
# ## How COVID-19 is Believed to have Started in South Korea

# %% [markdown]
# **Jan 20:** The country’s first known case was a 35-year-old Chinese woman who arrived at Incheon Airport in South Korea from Wuhan, China.
#
# **Jan 27:** Within a week, there were three more known cases, all travelers from Wuhan and all in their 50s. Two were detected and isolated at airports, so it is very unlikely they passed the disease to anyone else.
#
# **Jan 30:** Three additional people were confirmed to have the virus. Two were from Wuhan, and one was a man who had eaten a meal at a restaurant with Patient 3. He would become Patient 6, the first known case of local transmission in South Korea.
#
# **Jan 31:**  Patient 6’s wife and son were confirmed positive, as well. Eleven days after the first case was diagnosed, there were just 10 other known cases. Local transmission had occurred only among family members or within close social circles.
#
# **Feb 2:**  The first case of transmission between strangers was documented when an airline passenger tested positive after sitting near an infected person on a flight.
#
# **Feb 18:**  Patient 31, a 61-year-old woman, became the first congregant at Shincheonji Church of Jesus in Daegu to test positive. It was unclear where she contracted the virus. She's been criticized for reportedly ignoring symptoms, attending the church twice, lunching with friends and initially refusing to be tested for the virus because she hadn't recently traveled abroad.
#
# **Feb 20:**  Within two days after Patient 31 tested positive, 15 more people connected to the Shincheonji church were confirmed to have the virus. A month later, thousands of people with connections to the church would test positive for the virus. While the virus ravaged the church, more than 100 new cases had been confirmed in surrounding Daegu, as well. The disease appeared in hospitals, housing for the elderly and other churches. Most of these additional clusters were near the Shincheonji church.
#
# **Mar 25:**  The cluster at the Shincheonji church accounted for 5,080 confirmed cases of COVID-19, more than half of South Korea’s total. South Korea became the second most infected country after China.
#
# *How a South Korean Church Helped Fuel the Spread of the Coronavirus (Washington Post)<br>
# https://www.washingtonpost.com/graphics/2020/world/coronavirus-south-korea-church/?itid=ap_youjinshin*

# %% [markdown]
# ## COVID-19 Response in South Korea

# %% [markdown]
# Although the Lithuania's population and government have major difference with those of South Korea, there are lessons we can learn. South Korea is one of very few countries to avoid both mass lockdowns and mass deaths. Unlike many countries, South Korea has seen almost no domestic backlash to its pandemic approach. Businesses largely complied with mandatory curfews. There has been no successful anti-vaccine movement. Virtually everyone wore masks as required by government guidelines. About 90% of adults have received at least one dose the COVID-19 vaccine. During the pandemic it has always been possible to go shopping or eat at a restaurant. These facts make it even more important to understand how the members of Shincheonji church helped spread the virus during the period of my analysis.
#
# Korea Disease Control and Prevention Agency is the organization responsible for issues related to health in South Korea. After the country's biggest cluster of infections emerged among the Shincheonji church in Daegu, the South Korean government ordered testing on more than 200,000 members of the church across the country. Thousands tested positive for the virus. The government reacted quickly with other policies. This report will highlight some of government's efforts and its effects.
#
# The South Korean response is distinct in several respects:<br>
# **Early:** An early response after the first case on January 20. <br>
# **Speed:** Testing was rapid and widespread. <br>
# **Transparency:** Real-time and frequent information dissemination to the public. <br>
# **Public-Private sector:** Enlisting companies with needed resources to fight the disease. <br>
# **National organization:** Efforts were organized at the national level.
#
# *Policy and institutional responses to COVID-19: South Korea<br>*
# https://www.brookings.edu/research/policy-and-institutional-responses-to-covid-19-south-korea/

# %% [markdown]
# ## Current COVID-19 Data from South Korea

# %% [markdown]
# As of the date of this analysis, April 9, 2022, the COVID-19 numbers from South Korea are as follows:
#
# **Confirmed Cases:** 15,169,189 <br>
# **Deaths:** 19,0927,783
#
# *worldometer*<br>
# https://www.worldometers.info/coronavirus/country/south-korea/

# %% [markdown]
# ## COVID-19 and Shincheonji Church

# %% [markdown]
# Shincheonji was a church at the center of the first wave of COVID-19 pandemic. It is estimated to have over 300,000 members. At least 5,227 people linked to its followers became infected after attending a service in the city of Daegu.
#
# About 90% of the members was unvaccinated and the majority were in close contact through communal living. During their indoors meetings, members were tightly packed, which means infections among followers can spread quickly. Shincheonji Church worshipers were forbidden from wearing glasses and face masks during prayer services. Many of the members were in their 60s and above.
#
# In 2020, the outbreak of COVID-19 cases in South Korea was initially centered in the city of Daegu after a 61-year-old Shincheonji member known as Patient 31 infected other church members causing the pandemic to surge in Daegu.
#
# *Cult or church? This Korean sect has thousands of devotees, but ex-believers lost faith and money* <br>
# https://www.abc.net.au/news/2021-05-02/south-koreas-secretive-religious-sect/100101810
#
# *Shincheonji Church of Jesus* <br>
# https://en.wikipedia.org/wiki/Shincheonji_Church_of_Jesus
#
# *South Korea is on high alert after a coronavirus outbreak. Here's how a secretive sect became the perfect incubator* <br>
# https://www.abc.net.au/news/2020-02-24/how-coronavirus-hit-south-korea/11993682

# %% [markdown]
# # Libraries

# %%
import matplotlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import datetime

from IPython.display import display

# %% [markdown]
# # Functions

# %%
# To be Written

# %% [markdown]
# # Colors

# %%
ord_color = "bisque"
spec_lev1 = "crimson"
spec_lev2 = "orangered"
spec_lev3 = "lightcoral"

# %% [markdown]
# # Display Features

# %%
# %matplotlib inline
pd.set_option("max_rows", None)
pd.set_option("max_columns", None)

# %% [markdown]
# # Loading and Cleaning

# %% [markdown]
# ## Test Dataset

# %%
test = pd.read_csv("C:\py\Projects\TuringCollege\COVID19\DataSets\\test.csv", parse_dates =["date"], index_col ="date")

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 163 entries, 2020-01-20 to 2020-06-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   time       163 non-null    int64
#  1   test       163 non-null    int64
#  2   negative   163 non-null    int64
#  3   confirmed  163 non-null    int64
#  4   released   163 non-null    int64
#  5   deceased   163 non-null    int64
# dtypes: int64(6)
# memory usage: 8.9 KB

# %%
test = test.drop(["time", "released", "test", "negative", "deceased"], axis=1)

# %%
test.rename(
    columns={
        "confirmed": "Confirmed"  
    },
    inplace=True,
)
test.index.names = ['Date']

# %%
test.head()
# Out:
#             Confirmed
# Date
# 2020-01-20          1
# 2020-01-21          1
# 2020-01-22          1
# 2020-01-23          1
# 2020-01-24          2

# %% [markdown]
# ### Section Summary
# > * The data is a CSV file that I have downloaded from Kaggle.
# > * The original dataset contained 163 rows and 6 columns.
# > * This dataset has no missing data.
# > * While importing the dataset, I formatted the "date" column as datetime64 and renamed it to "Date."
# > * "Date" column is the index of this dataset.
# > * I deleted all columns except the column "Confirmed." The other columns were unneeded for my analysis.

# %% [markdown]
# ## Gender Dataset

# %%
gender = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\gender.csv",
    index_col=False,
    parse_dates=["date"],
    skipinitialspace=True,
)

# %%
gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       242 non-null    datetime64[ns]
#  1   time       242 non-null    int64
#  2   sex        242 non-null    object
#  3   confirmed  242 non-null    int64
#  4   deceased   242 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 9.6+ KB

# %%
gender = gender.drop(["time"], axis=1)

# %%
gender.rename(
    columns={
        "date": "Date",
        "sex": "Gender",
        "confirmed": "Confirmed",
        "deceased": "Deceased",
    },
    inplace=True,
)

# %%
gender.replace("male", "Male", inplace=True)
gender.replace("female", "Female", inplace=True)

# %%
gender.head()
# Out:
#         Date  Gender  Confirmed  Deceased
# 0 2020-03-02    Male       1591        13
# 1 2020-03-02  Female       2621         9
# 2 2020-03-03    Male       1810        16
# 3 2020-03-03  Female       3002        12
# 4 2020-03-04    Male       1996        20

# %% [markdown]
# ### Section Summary
# > * The data is a CSV file that I have downloaded from Kaggle.
# > * I created a Pandas dataframe object to work with the data.
# > * The original dataset contained 245 rows and 5 columns.
# > * This dataset has no missing data.
# > * While importing the dataset, I formatted the "date" column as datetime64 and renamed it to "Date."
# > * I renamed the columns so their names start with a capital letter.
# > * I renamed "male" and "female" in the "Gender" column to "Male" and "Female" starting with a capital letter.

# %% [markdown]
# ## Age Dataset

# %%
age = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\\age.csv",
    parse_dates=["date"],
    skipinitialspace=True,
)

# %%
age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1089 entries, 0 to 1088
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1089 non-null   datetime64[ns]
#  1   time       1089 non-null   int64
#  2   age        1089 non-null   object
#  3   confirmed  1089 non-null   int64
#  4   deceased   1089 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 42.7+ KB

# %%
age.rename(
    columns={
        "date": "Date",
        "age": "Age",
        "confirmed": "Confirmed",
        "deceased": "Deceased",
    },
    inplace=True,
)

# %%
age.drop("time", inplace=True, axis=1)

# %%
age.head()
# Out:
#         Date  Age  Confirmed  Deceased
# 0 2020-03-02   0s         32         0
# 1 2020-03-02  10s        169         0
# 2 2020-03-02  20s       1235         0
# 3 2020-03-02  30s        506         1
# 4 2020-03-02  40s        633         1

# %% [markdown]
# ### Section Summary
# > * The data is a CSV file that I have downloaded from Kaggle.
# > * I created a Pandas dataframe object to work with the data.
# > * The original dataset contained 1089 rows and 5 columns.
# > * This dataset has no missing data.
# > * While importing the dataset, I formatted the "date" column as datetime64 and renamed it to "Date."
# > * I deleted the column "time."
# > * I renamed the columns so their names start with a capital letter.

# %% [markdown]
# ## Population Dataset

# %%
population = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\population.csv",
    index_col=False,
    skipinitialspace=True,
)

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   code                      243 non-null    int64
#  1   province                  243 non-null    object
#  2   city                      243 non-null    object
#  3   latitude                  243 non-null    float64
#  4   longitude                 243 non-null    float64
#  5   elementary_school_count   243 non-null    int64
#  6   kindergarten_count        243 non-null    int64
#  7   university_count          243 non-null    int64
#  8   academy_ratio             243 non-null    float64
#  9   elderly_population_ratio  243 non-null    float64
#  10  elderly_alone_ratio       243 non-null    float64
#  11  nursing_home_count        243 non-null    int64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 22.9+ KB

# %%
population = population.drop(
    [
        "code",
        "city",
        "latitude",
        "longitude",
        "academy_ratio",
        "elderly_population_ratio",
        "elderly_alone_ratio",
    ],
    axis=1,
)

# %%
population.rename(
    columns={
        "province": "Province",
        "elementary_school_count": "Elem Schools",
        "kindergarten_count": "Kindergartens",
        "university_count": "Universities",
        "nursing_home_count": "Nursing Homes",
    },
    inplace=True,
)

# %%
population = population[
    [
        "Province",
        "Kindergartens",
        "Elem Schools",
        "Universities",
        "Nursing Homes",
    ]
]

# %%
population.head()
# Out:
#   Province  Kindergartens  Elem Schools  Universities  Nursing Homes
# 0    Seoul            830           607            48          22739
# 1    Seoul             38            33             0           3088
# 2    Seoul             32            27             0           1023
# 3    Seoul             21            14             0            628
# 4    Seoul             56            36             1           1080

# %% [markdown]
# ### Section Summary
# > * The data is a CSV file that I have downloaded from Kaggle.
# > * I created a Pandas dataframe object to work with the data.
# > * The original dataset contained 243 rows and 12 columns.
# > * This dataset has no missing data.
# > * I deleted 7 unneeded columns.
# > * I renamed the columns so their names start with a capital letter.
# > * I reordered the columns so the format will be more usable.

# %% [markdown]
# ## Province Dataset

# %%
province = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\province.csv",
    index_col=False,
    skipinitialspace=True,
)
province["date"] = province["date"].astype("datetime64[ns]")

# %%
province.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2771 entries, 0 to 2770
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       2771 non-null   datetime64[ns]
#  1   time       2771 non-null   int64
#  2   province   2771 non-null   object
#  3   confirmed  2771 non-null   int64
#  4   released   2771 non-null   int64
#  5   deceased   2771 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 130.0+ KB

# %%
province = province.drop(["time", "released", "deceased"], axis=1)

# %%
province.rename(
    columns={
       "date": "Date",
        "province": "Province",
        "confirmed": "Confirmed",
    },
    inplace=True,
)

# %%
province.head()
# Out:
#         Date Province  Confirmed
# 0 2020-01-20    Seoul          0
# 1 2020-01-20    Busan          0
# 2 2020-01-20    Daegu          0
# 3 2020-01-20  Incheon          1
# 4 2020-01-20  Gwangju          0

# %% [markdown]
# ### Section Summary
# > * The data is a CSV file that I have downloaded from Kaggle.
# > * I created a Pandas dataframe object to work with the data.
# > * The original dataset contained 2771 rows and 6 columns.
# > * This dataset has no missing data.
# > * I deleted 2 unneeded columns.
# > * I renamed the columns so their names start with a capital letter.

# %% [markdown]
# ## Case Dataset

# %%
case = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\\case.csv",
    index_col=False,
    skipinitialspace=True,
)

# %%
case.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   case_id         174 non-null    int64
#  1   province        174 non-null    object
#  2   city            174 non-null    object
#  3   group           174 non-null    bool
#  4   infection_case  174 non-null    object
#  5   confirmed       174 non-null    int64
#  6   latitude        174 non-null    object
#  7   longitude       174 non-null    object
# dtypes: bool(1), int64(2), object(5)
# memory usage: 9.8+ KB

# %%
case = case.drop(["case_id", "city", "group", "latitude", "longitude"], axis=1)

# %%
case = case[case.infection_case != "etc"]

# %%
case.rename(
    columns={
        "province": "Province",
        "infection_case": "Infection Reason",
        "confirmed": "Confirmed",
    },
    inplace=True,
)

# %%
case.replace("contact with patient", "Contact with Patient", inplace=True)
case.replace("overseas inflow", "Overseas Inflow", inplace=True)
case.replace("gym facility in Cheonan", "Gym Facility in Cheonan", inplace=True)
case.replace(
    "Door-to-door sales in Daejeon", "Door-to-Door Sales in Daejeon", inplace=True
)
case.replace("gym facility in Cheonan", "Gym Facility in Cheonan", inplace=True)
case.replace(
    "Geumcheon-gu rice milling machine manufacture",
    "Geumcheon-gu Rice Milling Machine Manufacture",
    inplace=True,
)
case.replace(
    "Lotte Confectionery logistics center",
    "Lotte Confectionery Logistics Center",
    inplace=True,
)
case.replace("gym facility in Sejong", "Gym Facility in Sejong", inplace=True)
case.replace(
    "Seoul City Hall Station safety worker",
    "Seoul City Hall Station Safety Worker",
    inplace=True,
)
case.replace(
    "Gangnam Yeoksam-dong gathering", "Gangnam Yeoksam-dong Gathering", inplace=True
)
case.replace(
    "Seongnam neighbors gathering", "Seongnam neighbors Gathering", inplace=True
)
case.replace(
    "Eunpyeong-Boksagol culture center",
    "Eunpyeong-Boksagol Culture Center",
    inplace=True,
)
case.replace(
    "Biblical Language study meeting", "Biblical Language Study Meeting", inplace=True
)
case.replace("Daejeon door-to-door sales", "Daejeon Door-to-Door Sales", inplace=True)

# %%
case.head()
# Out:
#   Province             Infection Reason  Confirmed
# 0    Seoul                Itaewon Clubs        139
# 1    Seoul                      Richway        119
# 2    Seoul          Guro-gu Call Center         95
# 3    Seoul  Yangcheon Table Tennis Club         43
# 4    Seoul              Day Care Center         43

# %% [markdown]
# ### Section Summary
# > * The data is a CSV file that I have downloaded from Kaggle.
# > * I created a Pandas dataframe object to work with the data.
# > * The original dataset contained 174 rows and 8 columns.
# > * This dataset has no missing data.
# > * I deleted 5 unneeded columns.
# > * I renamed the columns so their names start with a capital letter.
# > * I replaced many of the column values to start with capital letters.

# %% [markdown]
# ## Patient Dataset

# %%
patient = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\patient.csv",
    index_col=False,
    skipinitialspace=True,
)

# %%
patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5165 entries, 0 to 5164
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  5165 non-null   int64
#  1   sex                 4043 non-null   object
#  2   age                 3785 non-null   object
#  3   country             5165 non-null   object
#  4   province            5165 non-null   object
#  5   city                5071 non-null   object
#  6   infection_case      4246 non-null   object
#  7   infected_by         1346 non-null   object
#  8   contact_number      791 non-null    object
#  9   symptom_onset_date  689 non-null    object
#  10  confirmed_date      5162 non-null   object
#  11  released_date       1587 non-null   object
#  12  deceased_date       66 non-null     object
#  13  state               5165 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 565.0+ KB

# %%
patient = patient.drop(
    [
        "ID",
        "city",
        "infected_by",
        "contact_number",
        "symptom_onset_date",
        "released_date",
        "deceased_date",
        "state",
        "confirmed_date",
    ],
    axis=1,
)

# %%
patient.rename(
    columns={
        "sex": "Gender",
        "age": "Age",
        "infection_case": "Infection Reason",
        "country": "Country",
        "province": "Province",
        "city": "City",
    },
    inplace=True,
)

# %%
patient.replace("overseas inflow", "Overseas Inflow", inplace=True)
patient.replace("contact with patient", "Contact with Patient", inplace=True)
patient.replace("male", "Male", inplace=True)
patient.replace("female", "Female", inplace=True)

# %%
patient["Infection Reason"] = patient["Infection Reason"].str.replace("etc", "MISSING")

# %%
patient.head()
# Out:
#    Gender  Age Country Province      Infection Reason
# 0    Male  50s   Korea    Seoul       Overseas Inflow
# 1    Male  30s   Korea    Seoul       Overseas Inflow
# 2    Male  50s   Korea    Seoul  Contact with Patient
# 3    Male  20s   Korea    Seoul       Overseas Inflow
# 4  Female  20s   Korea    Seoul  Contact with Patient

# %% [markdown]
# ### Section Summary
# > * The data is a CSV file that I have downloaded from Kaggle.
# > * I created a Pandas dataframe object to work with the data.
# > * The original dataset contained 5165 rows and 14 columns.
# > * This dataset has many data values missing. I indicated all missing values and all values indicated by "etc" with the word, "MISSING"
# > * I deleted 9 unneeded columns.
# > * I renamed the columns so their names start with a capital letter.
# > * I replaced many of the column values to start with capital letters.

# %% [markdown]
# ## Policy Dataset

# %%
policy = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\\policy.csv",
    parse_dates=["start_date"],
    index_col = 'start_date'
)

# %%
policy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 61 entries, 2020-01-03 to 2020-05-28
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   policy_id   61 non-null     int64
#  1   country     61 non-null     object
#  2   type        61 non-null     object
#  3   gov_policy  61 non-null     object
#  4   detail      59 non-null     object
#  5   end_date    24 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 3.3+ KB

# %%
policy = policy.drop(
    [
        "policy_id",
        "country",
        "type",
        "detail",
        "end_date"
    ],
    axis=1,
)

# %%
policy.rename(
    columns={
        "gov_policy": "Policy",     
    },
    inplace=True,
)

# %%
policy.replace('Close bars and clubs', 'Close Bars and Clubs', inplace=True)
policy.replace('local government Administrative orders', 'Local Government Administrative Orders', inplace=True)
policy.replace('Close karaoke', 'Close Karaoke', inplace=True)
policy.replace('Logistics center', 'Logistics Center', inplace=True)
policy.replace('Thanks to Challenge korea', 'Thanks to Challenge Korea', inplace=True)
policy.replace('Wearing of masks', 'Wearing of Masks', inplace=True)

# %%
policy.head()
# Out:
#                                     Policy
# start_date
# 2020-01-03  Infectious Disease Alert Level
# 2020-01-20  Infectious Disease Alert Level
# 2020-01-28  Infectious Disease Alert Level
# 2020-02-23  Infectious Disease Alert Level
# 2020-02-04   Special Immigration Procedure

# %% [markdown]
# ## Population Dataset

# %%
population_size = {
    "Population": pd.Series(
        [
            3468139,
            2640441,
            9975709,
            13511676,
            2938457,
            2176636,
            3333056,
            1545717,
            1632088,
            1521763,
            1138225,
            353933,
            1526000,
            1797031,
            1788807,
            670858,
            2184528,
        ],
        index=[
            "Busan",
            "Gyeongsangbuk-do",
            "Seoul",
            "Gyeonggi-do",
            "Incheon",
            "Chungcheongnam-do",
            "Gyeongsangnam-do",
            "Daejeon",
            "Chungcheongbuk-do",
            "Gangwon-do",
            "Ulsan",
            "Sejong",
            "Gwangju",
            "Jeollabuk-do",
            "Jeollanam-do",
            "Jeju-do",
            "Daegu"           
        ],
    )
}

population_size = pd.DataFrame(population_size)
population_size.index.names = ['Province']
population_size
# Out:
#                    Population
# Province
# Busan                 3468139
# Gyeongsangbuk-do      2640441
# Seoul                 9975709
# Gyeonggi-do          13511676
# Incheon               2938457
# Chungcheongnam-do     2176636
# Gyeongsangnam-do      3333056
# Daejeon               1545717
# Chungcheongbuk-do     1632088
# Gangwon-do            1521763
# Ulsan                 1138225
# Sejong                 353933
# Gwangju               1526000
# Jeollabuk-do          1797031
# Jeollanam-do          1788807
# Jeju-do                670858
# Daegu                 2184528

# %% [markdown]
# ### Section Summary
# > * The data is a CSV file that I have downloaded from Kaggle.
# > * I created a Pandas dataframe object to work with the data.
# > * The original dataset contained 5165 rows and 14 columns.
# > * This dataset has many data values missing. I indicated all missing values and all values indicated by "etc" with the word, "MISSING"
# > * I deleted 9 unneeded columns.
# > * I renamed the columns so their names start with a capital letter.
# > * I replaced many of the column values to start with capital letters.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## How Did the Number of Infections Change Over Time?

# %%
test_by_month = test.asfreq(freq="M")
test_by_month = test_by_month.reset_index()
test_by_month["Month"] = test_by_month["Date"].dt.strftime("%B")

# %%
plt.figure(figsize=(10, 10))
sns.set(style="whitegrid")

sns.lineplot(
    x="Month",
    y="Confirmed",
    data=test_by_month,
    marker="o",
    markeredgecolor="b",
    color=spec_lev1,
    linewidth=2.5,
    markers=True,
)

plt.xlabel("Month", fontsize=25, labelpad=15)
plt.ylabel("Confirmed Cases", fontsize=25, labelpad=15)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.title("Confirmed Cases January to June 2020", fontsize=30, y=1.05)

for x, y in zip(test_by_month["Month"], test_by_month["Confirmed"]):
    plt.text(x=x, y=y - 350, s="{:.0f}".format(y), color="black")

sns.despine(left=True, bottom=True)


plt.show()

# %% [markdown]
# ### Section Summary
# > * The data is a CSV file that I have downloaded from Kaggle.
# > * I created a Pandas dataframe object to work with the data.
# > * The original dataset contained 5165 rows and 14 columns.
# > * This dataset has many data values missing. I indicated all missing values and all values indicated by "etc" with the word, "MISSING"
# > * I deleted 9 unneeded columns.
# > * I renamed the columns so their names start with a capital letter.
# > * I replaced many of the column values to start with capital letters.

# %% [markdown]
# ## What was the Effect of Government Measures on COVID-19 Infections?

# %%
test_count = test.copy()

test_count['Count'] = test_count['Confirmed'].diff().fillna(0)
test_count.drop('Confirmed', inplace = True, axis = 1)

# %%
policy.index.names = ['Date']
policy.drop_duplicates(keep="first", inplace=True)
policy.reset_index()
policy = policy.sort_values('Date', ascending = True)

# %%
test_count.reset_index(inplace=True)
policy.reset_index(inplace=True)

df_outer = pd.merge(test_count, policy, on='Date', how='outer')

df_outer = df_outer.dropna(how='any')
df_outer['Date'] = df_outer['Date'].astype(str)
# df_outer.drop(df_outer.index[df_outer['Policy'] == "Open Data"], inplace = True)
df_outer.drop(df_outer.index[[0,1,2,3,8,10,14,17,21]], inplace=True)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.set(style="whitegrid")

ax = sns.lineplot(
    x="Date",
    y="Count",
    data=df_outer,
    marker="o",
    markeredgecolor="b",
    color="crimson",
    linewidth=2.5,
    markers=True,
)

ax.annotate('Social Distancing Campaign',
            xy=('2020-02-29', 813.0),
            xycoords='data',
            xytext=(-200, 10),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='black'),
            ha='center',
            va='center',
            fontsize=15)

ax.annotate('Self-Quarantine Safety Protection App',
            xy=('2020-03-07', 483.0),
            xycoords='data',
            xytext=(200, 0),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='black'),
            ha='center',
            va='center',
            fontsize=15)

ax.annotate('Mandatory 14-day Self-Quarantine',
            xy=('2020-04-01', 101.0),
            xycoords='data',
            xytext=(-200, 0),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='black'),
            ha='center',
            va='center',
            fontsize=15)

ax.annotate('Extends Tightened Quarantine Measures',
            xy=('2020-05-28', 79.0),
            xycoords='data',
            xytext=(-200, 0),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='black'),
            ha='center',
            va='center',
            fontsize=15)

plt.title("Confirmed Cases January to June 2020", fontsize=30, y=1.05)
sns.despine(left=True, bottom=True)
plt.show();

# %% [markdown]
# ### Section Summary
# > *

# %% [markdown]
# ## What is the Difference between how Different Genders Got Infected and Died?

# %%
confirmed = (
    gender[["Gender", "Confirmed"]]
    .groupby(["Gender"])
    .max()
    .sort_values("Confirmed", ascending=False)
)
confirmed = confirmed.reset_index()

# %%
sns.set_context("paper", font_scale=2.0)

confirmed = (
    gender[["Gender", "Confirmed"]]
    .groupby(["Gender"])
    .max()
    .sort_values("Confirmed", ascending=False)
)
confirmed = confirmed.reset_index()

deceased = (
    gender[["Gender", "Deceased"]]
    .groupby(["Gender"])
    .max()
    .sort_values("Deceased", ascending=True)
)
deceased = deceased.reset_index()

data_confirmed = [confirmed.loc[0, "Confirmed"], confirmed.loc[1, "Confirmed"]]
labels_confirmed = ["Female", "Male"]
colors_confirmed = [spec_lev1, ord_color]

data_deceased = [deceased.loc[1, "Deceased"], deceased.loc[0, "Deceased"]]
labels_deceased = ["Male", "Female"]
colors_deceased = [spec_lev1, ord_color]


fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 15))

ax1.set_title("Confirmed According to Gender")
ax1.pie(
    data_confirmed,
    labels=labels_confirmed,
    colors=colors_confirmed,
    autopct="%0.0f%%",
    startangle=90,
    wedgeprops={"edgecolor": "black", "linewidth": 1},
)


ax2.set_title("Deceased According to Gender")
ax2.pie(
    data_deceased,
    labels=labels_deceased,
    colors=colors_deceased,
    autopct="%0.0f%%",
    startangle=90,
    wedgeprops={"edgecolor": "black", "linewidth": 1},
)

plt.show()

# %% [markdown]
# ### Section Summary
# > * Although more women were infected by COVID-19 (57%), slightly more men (54%) actually died from COVID-19.
# > * The data could possibly suggest that we may need to pay more attention at reducing the number of infections by women and the number of deaths by men.
# > * The reason for a higher number of infections by because of women socializing more in the South Korean Society, but the exact reasons for these differences has to be investigated further.

# %% [markdown]
# ## Did Age Affect who Got COVID and Who Died from it?

# %%
confirmed_by_age = (
    age[["Age", "Confirmed"]]
    .groupby(["Age"])
    .max()
    .sort_values("Confirmed", ascending=False)
)

confirmed_by_age = confirmed_by_age.reset_index()

# %%
plt.figure(figsize=(20, 8))
sns.set(style="whitegrid")
sns.set_context("paper", font_scale=2.0)

ord_color = "bisque"
spec_lev1 = "red"
spec_lev2 = "orangered"
spec_lev3 = "lightcoral"

palette = {
    "0s": ord_color,
    "10s": ord_color,
    "20s": spec_lev1,
    "30s": ord_color,
    "40s": ord_color,
    "50s": ord_color,
    "60s": ord_color,
    "70s": ord_color,
    "80s": ord_color,
}

sns.stripplot(
    data=age,
    x="Age",
    y="Confirmed",
    jitter=0.25,
    size=8,
    linewidth=0.2,
    edgecolor="black",
    palette=palette,
)

plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("Age", fontsize=25, labelpad=25)
plt.ylabel("Confirmed", fontsize=25, labelpad=25)
plt.title("Confirmed According to Age", fontsize=30, y=1.05)

plt.show()

# %% [markdown]
# ### Section Summary
# > * The data is a CSV file that I have downloaded from Kaggle.
# > * I created a Pandas dataframe object to work with the data.
# > * The original dataset contained 5165 rows and 14 columns.
# > * This dataset has many data values missing. I indicated all missing values and all values indicated by "etc" with the word, "MISSING"
# > * I deleted 9 unneeded columns.
# > * I renamed the columns so their names start with a capital letter.
# > * I replaced many of the column values to start with capital letters.

# %%
deceased_by_age = (
    age[["Age", "Deceased"]]
    .groupby(["Age"])
    .max()
    .sort_values("Deceased", ascending=False)
)

deceased_by_age = deceased_by_age.reset_index()

# %%
plt.figure(figsize=(15, 8))
sns.set(style="whitegrid")
sns.set_context("paper", font_scale=2.0)

ord_color = "bisque"
spec_lev1 = "red"
spec_lev2 = "orangered"
spec_lev3 = "lightcoral"

palette = {
    "0s": ord_color,
    "10s": ord_color,
    "20s": ord_color,
    "30s": ord_color,
    "40s": ord_color,
    "50s": ord_color,
    "60s": spec_lev3,
    "70s": spec_lev2,
    "80s": spec_lev1,
}

sns.stripplot(
    data=age,
    x="Age",
    y="Deceased",
    jitter=0.25,
    size=8,
    linewidth=0.2,
    edgecolor="Black",
    palette=palette,
)

plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("Age", fontsize=25, labelpad=25)
plt.ylabel("Deceased", fontsize=25, labelpad=25)
plt.title("Deceased According to Age", fontsize=30, y=1.05)

plt.show()

# %% [markdown]
# ## Why does Daegu Have the Majority of COVID19 Infections?

# %%
province_all = (
    province[["Province", "Confirmed"]].groupby(["Province"]).max()
)
df_inner = pd.merge(province_all, population_size, on='Province', how='inner')
df_inner = df_inner [["Population", "Confirmed"]]
df_inner = df_inner.reset_index()

# %%
plt.figure(figsize=(20, 15))
sns.set(style="white")
sns.set_context("paper", font_scale=2.0)

plt.title("Daegu is Sixth in Population", fontsize=30, y=1)

palette = {
    "Daegu": spec_lev1,
    "Gyeongsangbuk-do": ord_color,
    "Seoul": ord_color,
    "Gyeonggi-do": ord_color,
    "Incheon": ord_color,
    "Chungcheongnam-do": ord_color,
    "Gyeongsangnam-do": ord_color,
    "Daejeon": ord_color,
    "Chungcheongbuk-do": ord_color,
    "Gangwon-do": ord_color,
    "Ulsan": ord_color,
    "Sejong": ord_color,
    "Gwangju": ord_color,
    "Jeollabuk-do": ord_color,
    "Jeollanam-do": ord_color,
    "Jeju-do": ord_color,
    "Busan": ord_color
}

chart = sns.barplot(
    x="Province",
    y="Population",
    ci=None,
    dodge=False,
    data=df_inner,
    order=df_inner.sort_values("Population", ascending=False).Province,
    palette=palette,
)

plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("Locations", fontsize=25, labelpad=25)
plt.ylabel("Infections", fontsize=25, labelpad=25)

sns.despine(left=True, bottom=True)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment="right")

plt.show()

# %%
pd.set_option("display.max.columns", None)
pivot_nursing_homes = pd.pivot_table(
    data=population,
    index="Province",
    values=["Nursing Homes"],
    aggfunc="sum",
)

pivot_nursing_homes = pivot_nursing_homes.sort_values("Nursing Homes", ascending=False)
pivot_nursing_homes.reset_index(inplace=True)

# %%
sns.set(style="white")

palette = {
    "Daegu": spec_lev1,
    "Gyeongsangbuk-do": ord_color,
    "Seoul": ord_color,
    "Gyeonggi-do": ord_color,
    "Incheon": ord_color,
    "Chungcheongnam-do": ord_color,
    "Gyeongsangnam-do": ord_color,
    "Daejeon": ord_color,
    "Chungcheongbuk-do": ord_color,
    "Gangwon-do": ord_color,
    "Ulsan": ord_color,
    "Sejong": ord_color,
    "Gwangju": ord_color,
    "Jeollabuk-do": ord_color,
    "Jeollanam-do": ord_color,
    "Jeju-do": ord_color,
    "Busan": ord_color
}


plt.figure(figsize=(15, 8))
chart = sns.barplot(
    x="Province",
    y="Nursing Homes",
    data=pivot_nursing_homes,
    ci=None,
    order=pivot_nursing_homes.sort_values("Nursing Homes", ascending=False).Province,
    palette=palette,
)

sns.despine(left=True, bottom=True)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Location", fontsize=25, labelpad=25)
plt.ylabel("Nursing Homes", fontsize=25, labelpad=25)

plt.title("Daegu is Fifth in the Number of Nursing Homes", fontsize=30, y=1.1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment="right")

plt.show()

# %%
academic = population.groupby(["Province"])[
    ["Kindergartens", "Elem Schools", "Universities"]
].agg(sum)

academic = academic.reset_index()
academic["Total"] = academic.sum(axis=1)
academic = academic.sort_values("Total", ascending=False)
academic = academic.sort_values("Total", ascending=False)

# %%
sns.set(style="white")

palette = {
    "Daegu": spec_lev1,
    "Gyeongsangbuk-do": ord_color,
    "Seoul": ord_color,
    "Gyeonggi-do": ord_color,
    "Incheon": ord_color,
    "Chungcheongnam-do": ord_color,
    "Gyeongsangnam-do": ord_color,
    "Daejeon": ord_color,
    "Chungcheongbuk-do": ord_color,
    "Gangwon-do": ord_color,
    "Ulsan": ord_color,
    "Sejong": ord_color,
    "Gwangju": ord_color,
    "Jeollabuk-do": ord_color,
    "Jeollanam-do": ord_color,
    "Jeju-do": ord_color,
    "Busan": ord_color
}


plt.figure(figsize=(15, 8))
chart = sns.barplot(
    x="Province",
    y="Total",
    data=academic,
    ci=None,
    order=academic.sort_values("Total", ascending=False).Province,
    palette=palette,
)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.title("Daegu is twelveth in the Number of Academic Institutions", fontsize=30, y=1.1)
plt.xlabel("Location", fontsize=25, labelpad=25)
plt.ylabel("Academic Institutions", fontsize=25, labelpad=25)

chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment="right")
sns.despine(left=True, bottom=True)

plt.show();

# %%
groupby_province = (
    province[["Province", "Confirmed"]]
    .groupby(["Province"])
    .max()
    .sort_values("Confirmed", ascending=False)
)

groupby_province = groupby_province.reset_index()

# %%
plt.figure(figsize=(20, 15))
sns.set(style="white")
sns.set_context("paper", font_scale=2.0)

plt.title("Daegu is First in the Number of Infections", fontsize=30, y=1)

palette = {
    "Daegu": spec_lev1,
    "Gyeongsangbuk-do": ord_color,
    "Seoul": ord_color,
    "Gyeonggi-do": ord_color,
    "Incheon": ord_color,
    "Chungcheongnam-do": ord_color,
    "Gyeongsangnam-do": ord_color,
    "Daejeon": ord_color,
    "Chungcheongbuk-do": ord_color,
    "Gangwon-do": ord_color,
    "Ulsan": ord_color,
    "Sejong": ord_color,
    "Gwangju": ord_color,
    "Jeollabuk-do": ord_color,
    "Jeollanam-do": ord_color,
    "Jeju-do": ord_color,
    "Busan": ord_color
}

chart = sns.barplot(
    x="Province",
    y="Confirmed",
    ci=None,
    dodge=False,
    data=groupby_province,
    order=groupby_province.sort_values("Confirmed", ascending=False).Province,
    palette=palette,
)

plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("Locations", fontsize=25, labelpad=25)
plt.ylabel("Confirmed", fontsize=25, labelpad=25)

sns.despine(left=True, bottom=True)
chart.bar_label(chart.containers[0], size=25)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment="right")

plt.show()

# %% [markdown]
# ### Section Summary
# > * Daegu has the highest number of confirmed cases mainly due to the infections that started at the Shincheonji Church in that city.

# %% [markdown]
# ### Section Summary
# > * The data suggests clearly that provinces with the highest number of nursing homes were not the ones with the highest number of COVID-19 cases. Daegu has the higheset number of COVID-19 cases, yet, the number of nursing homes in that city is lower than Seoul by a factor of 4.

# %% [markdown]
# ### Section Summary
# > * The data suggests clearly that provinces with the highest number of academic institutions were not the ones with the highest number of COVID-19 cases. Daegu has the higheset number of COVID-19 cases, yet the number of academic institutions in that city is lower than Seoul by a factor of 3.

# %% [markdown]
# ## Why were  Shincheonji Church Members Linked to the Majority of COVID19 Infections?

# %%
pivot_infection = pd.pivot_table(
    data=case, index=["Infection Reason"], values="Confirmed", aggfunc="sum"
).sort_values("Confirmed", ascending=False)

total = pivot_infection["Confirmed"].sum()

pivot_province = pd.pivot_table(
    data=case, index=["Province"], values="Confirmed", aggfunc="sum"
).sort_values("Confirmed", ascending=False)

daegu = pivot_province.loc["Daegu"]
daegu = daegu["Confirmed"]


shincheonji_church_daegu = case.loc[
    (case["Province"] == "Daegu") & (case["Infection Reason"] == "Shincheonji Church")
]
shincheonji_church_daegu = shincheonji_church_daegu.set_index("Infection Reason")
shincheonji_church_daegu = shincheonji_church_daegu.loc["Shincheonji Church"]
shincheonji_church_daegu = shincheonji_church_daegu["Confirmed"]

other_daegu = daegu - shincheonji_church_daegu


shincheonji_church = pivot_infection.loc["Shincheonji Church"]
shincheonji_church = shincheonji_church["Confirmed"]

other_overall = total - shincheonji_church

# %%
sns.set_context("paper", font_scale=2.0)

data_shincheonji_church_SK = [shincheonji_church, other_overall]
labels_shincheonji_church_SK = ["Shincheonji Church", "Other Infections"]
colors_shincheonji_church_SK = [spec_lev1, ord_color]

data_shincheonji_church_daegu = [shincheonji_church_daegu, other_daegu]
labels_shincheonji_church_daegu = ["Shincheonji Church", "Other Infections"]
colors_shincheonji_church_daegu = [spec_lev1, ord_color]

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 15))

ax1.set_title("Shincheonji Church in South Korea")
ax1.pie(
    data_shincheonji_church_SK,
    labels=labels_shincheonji_church_SK,
    colors=colors_shincheonji_church_SK,
    startangle=90,
    autopct="%0.0f%%",
    wedgeprops={"edgecolor": "black", "linewidth": 1},
    textprops={"fontsize": 15},
)

ax2.set_title("Shincheonji Church in Daegu Province")
ax2.pie(
    data_shincheonji_church_daegu,
    labels=labels_shincheonji_church_daegu,
    colors=colors_shincheonji_church_daegu,
    startangle=90,
    autopct="%0.0f%%",
    wedgeprops={"edgecolor": "black", "linewidth": 1},
    textprops={"fontsize": 15},
)


plt.tight_layout()
plt.show();

# %% [markdown]
# ### Section Summary
# > * The data clearly suggests that infections linked to Shincheonji Church account for about half of all infections in South Korea between January and June 2020. These infections began at the church branch in Daegu.

# %% [markdown]
# # Conclusions

# %% [markdown]
# 1. The cooperation of all segments of the population is necessary for controlling a pandemic.
#
# > * <br>
# > * <br>
# > * <br>
#
# 2. Women more than men are more likely to get infected by COVID-19.
#
# > * <br>
# > * <br>
#
# 3. Men, more than womena are more likely to die from COVID-19.
#
# > *  <br>
# > *  <br>
#
#
# 4. Younger people more than older people are more likely to get infected by COVID-19.
#
# > *  <br>
#
#
# 5. Older people more than younger people are more likely to die from COVID-19.
#
# > * <br>
#
#
# 6. Close human contact is likely the way most people get infected.
#
# > *  <br>
# > *  <br>

# %% [markdown]
# # Recommendations for the Lithuanian Government

# %% [markdown]
# 1. Create an effective campaign to educating the public.
# > * <br>
# > * <br>
# > * <br>
# 2. Concentrate efforts on fringe groups that may not heed to government guidelines.
# > * <br>
# > * <br>
# > * <br>
# 3. Concentrate efforts on vaccinating the older population early to prevent death.
# > * <br>
# > * <br>
# > * <br>
# 3. Investigate the causes of the slightly higher number of men dying from COVID-19.
# > * <br>
# > * <br>
# > * <br>

# %% [markdown]
# # Suggestions for Improvement

# %% [markdown]
# 1. Does South Korea have different percentages of male and female?
# > * <br>
# > * <br>
# > * <br>
