# %% [markdown]
# # COVID 19

# %% [markdown]
# # Introduction

# %% [markdown]
# # Goals

# %% [markdown]
# # Technical Requirements

# %% [markdown]
# # Libraries

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

sns.set_palette("pastel")

# %% [markdown]
# # Datasets

# %% [markdown]
# ## Age

# %%
age = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\\age.csv",
    index_col=0,
    skipinitialspace=True,
)

# %%
# Deletes time column.
age = age.drop(["time"], axis=1)

# %%
# Modifies column names.
age.rename(
    columns={
        "age": "Age",
        "confirmed": "Confirmed",
        "deceased": "Deceased",
    },
    inplace=True,
)

# %%
groupby_age = age[['Age', 'Confirmed', 'Deceased']].groupby(['Age']).sum()

# %%
groupby_age["Percentage"] = (
    groupby_age["Deceased"] / groupby_age["Confirmed"]
) * 100
groupby_age['Percentage'] = groupby_age['Percentage'].apply('{:,.2f}'.format).astype('float64')

groupby_age.sort_values('Percentage', ascending = False)
# Out:
#      Confirmed  Deceased  Percentage
# Age
# 80s      54086     12136       22.44
# 70s      82107      7599        9.25
# 60s     158505      3743        2.36
# 50s     230030      1537        0.67
# 40s     168250       295        0.18
# 30s     137539       194        0.14
# 0s       16107         0        0.00
# 10s      68752         0        0.00
# 20s     345827         0        0.00

# %% [markdown]
# ## Gender

# %%
gender = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\gender.csv",
    index_col=0,
    skipinitialspace=True,
)

# %%
# Deletes time column.
gender = gender.drop(["time"], axis=1)

# %%
# Modifies column names.
gender.rename(
    columns={
        "sex": "Sex",
        "confirmed": "Confirmed",
        "deceased": "Deceased",
    },
    inplace=True,
)

# %%
groupby_gender = gender[['Sex', 'Confirmed', 'Deceased']].groupby(['Sex']).sum()

# %%
groupby_gender["Percentage"] = (
    groupby_gender["Deceased"] / groupby_gender["Confirmed"]
) * 100
groupby_gender['Percentage'] = groupby_gender['Percentage'].apply('{:,.2f}'.format).astype('float64')
groupby_gender.sort_values('Percentage', ascending = False)
# Out:
#         Confirmed  Deceased  Percentage
# Sex
# male       513727     13484        2.62
# female     747467     12019        1.61

# %% [markdown]
# ## Province

# %%
province = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\province.csv",
    index_col=0,
    skipinitialspace=True,
)

# %%
# Deletes time column.
province = province.drop(["time", "released"], axis=1)

# %%
# Modifies column names.
province.rename(
    columns={
        "province": "Province",
        "confirmed": "Confirmed",
        "deceased": "Deceased",
    },
    inplace=True,
)

# %%
groupby_province = province[['Province', 'Confirmed', 'Deceased']].groupby(['Province']).sum()

# %%
groupby_province["Percentage"] = (
    groupby_province["Deceased"] / groupby_province["Confirmed"]
) * 100
groupby_province['Percentage'] = groupby_province['Percentage'].apply('{:,.2f}'.format).astype('float64')
groupby_province.sort_values('Percentage', ascending = False)
# Out:
#                    Confirmed  Deceased  Percentage
# Province
# Gangwon-do              5908       225        3.81
# Gyeongsangbuk-do      161079      5393        3.35
# Daegu                 807506     17624        2.18
# Gyeonggi-do            81059      1600        1.97
# Busan                  16341       299        1.83
# Ulsan                   5269        91        1.73
# Daejeon                 5217        58        1.11
# Seoul                  81923       298        0.36
# Incheon                16645        16        0.10
# Gwangju                 3359         0        0.00
# Chungcheongnam-do      16780         0        0.00
# Chungcheongbuk-do       5801         0        0.00
# Gyeongsangnam-do       13860         0        0.00
# Jeju-do                 1449         0        0.00
# Jeollabuk-do            2108         0        0.00
# Jeollanam-do            1763         0        0.00
# Sejong                  5111         0        0.00

# %% [markdown]
# ## Patient

# %%
patient = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\patient.csv",
    index_col=False,
    skipinitialspace=True,
)

# %%
# Deletes unneeded columns.
patient = patient.drop(
    [
        "country",
        "province",
        "city",
        "symptom_onset_date",
        "confirmed_date",
        "released_date",
        "deceased_date",
        "state",
        "infected_by",
        "contact_number",
        "ID"
    ],
    axis=1,
)

# %%
# Modifies column names.
patient.rename(
    columns={
        "sex": "Sex",
        "age": "Age",
        "infection_case": "Infection",      
    },
    inplace=True,
)

# %%
pd.reset_option('display.max_rows')
Total = patient['Infection'].value_counts()
Total
# Out:
# contact with patient                             1610
# overseas inflow                                   840
# etc                                               703
# Itaewon Clubs                                     162
# Richway                                           128
# Guro-gu Call Center                               112
# Shincheonji Church                                107
# Coupang Logistics Center                           80
# Yangcheon Table Tennis Club                        44
# Day Care Center                                    43
# SMR Newly Planted Churches Group                   36
# Onchun Church                                      33
# Bonghwa Pureun Nursing Home                        31
# gym facility in Cheonan                            30
# Ministry of Oceans and Fisheries                   28
# Wangsung Church                                    24
# Cheongdo Daenam Hospital                           21
# Dongan Church                                      17
# Eunpyeong St. Mary's Hospital                      16
# Gyeongsan Seorin Nursing Home                      15
# Dunsan Electronics Town                            13
# KB Life Insurance                                  13
# Seongdong-gu APT                                   13
# Gyeongsan Jeil Silver Town                         12
# Milal Shelter                                      11
# Gyeongsan Cham Joeun Community Center              10
# Samsung Medical Center                              7
# Korea Campus Crusade of Christ                      7
# Orange Town                                         7
# Geochang Church                                     6
# Geumcheon-gu rice milling machine manufacture       6
# Gangnam Yeoksam-dong gathering                      6
# Seocho Family                                       5
# Guri Collective Infection                           5
# Yeonana News Class                                  5
# Yongin Brothers                                     4
# gym facility in Sejong                              4
# Changnyeong Coin Karaoke                            4
# Samsung Fire & Marine Insurance                     4
# Daezayeon Korea                                     3
# Biblical Language study meeting                     3
# Seoul City Hall Station safety worker               3
# Suyeong-gu Kindergarten                             3
# Yeongdeungpo Learning Institute                     3
# Pilgrimage to Israel                                2
# Uiwang Logistics Center                             2
# Gangnam Dongin Church                               1
# Orange Life                                         1
# River of Grace Community Church                     1
# Anyang Gunpo Pastors Group                          1
# Daejeon door-to-door sales                          1
# Name: Infection, dtype: int64

# %% [markdown]
# ## Case

# %%
case = pd.read_csv(
    "C:\py\Projects\TuringCollege\COVID19\DataSets\case.csv",
    index_col=False,
    skipinitialspace=True,
)

# %%
# Deletes time column.
case = case.drop(["case_id", "latitude", "longitude"], axis=1)

# %%
# Modifies column names.
case.rename(
    columns={
        "province": "Province",
        "city": "City",
        "group": "Group",
        "infection_case": "Location",
        "confirmed": "Confirmed",
        
    },
    inplace=True,
)
case.head()
# Out:
#   Province          City  Group                     Location  Confirmed
# 0    Seoul    Yongsan-gu   True                Itaewon Clubs        139
# 1    Seoul     Gwanak-gu   True                      Richway        119
# 2    Seoul       Guro-gu   True          Guro-gu Call Center         95
# 3    Seoul  Yangcheon-gu   True  Yangcheon Table Tennis Club         43
# 4    Seoul     Dobong-gu   True              Day Care Center         43

# %%
case = case[
    ["Province", "City", "Location", "Confirmed", "Group"]
]
pd.set_option("max_rows", None)
case.sort_values(['Location', 'Confirmed'], ascending=[False, False])
# Out:
#               Province             City  \
# 109        Gyeonggi-do                -
# 35               Seoul                -
# 67             Incheon                -
# 55               Daegu                -
# 45               Busan                -
# 167   Gyeongsangnam-do                -
# 81               Ulsan                -
# 60             Gwangju                -
# 155   Gyeongsangbuk-do                -
# 117         Gangwon-do                -
# 132  Chungcheongnam-do                -
# 77             Daejeon                -
# 142       Jeollanam-do                -
# 170            Jeju-do                -
# 124  Chungcheongbuk-do                -
# 138       Jeollabuk-do                -
# 87              Sejong                -
# 85              Sejong           Sejong
# 127  Chungcheongnam-do       Cheonan-si
# 57               Daegu                -
# 157   Gyeongsangbuk-do                -
# 37               Seoul                -
# 111        Gyeonggi-do                -
# 47               Busan                -
# 169   Gyeongsangnam-do                -
# 79             Daejeon                -
# 134  Chungcheongnam-do                -
# 69             Incheon                -
# 126  Chungcheongbuk-do                -
# 83               Ulsan                -
# 119         Gangwon-do                -
# 139       Jeollabuk-do                -
# 144       Jeollanam-do                -
# 172            Jeju-do                -
# 62             Gwangju                -
# 89              Sejong                -
# 56               Daegu                -
# 156   Gyeongsangbuk-do                -
# 36               Seoul                -
# 110        Gyeonggi-do                -
# 46               Busan                -
# 78             Daejeon                -
# 125  Chungcheongbuk-do                -
# 68             Incheon                -
# 168   Gyeongsangnam-do                -
# 61             Gwangju                -
# 143       Jeollanam-do                -
# 82               Ulsan                -
# 88              Sejong                -
# 133  Chungcheongnam-do                -
# 118         Gangwon-do                -
# 171            Jeju-do                -
# 30               Seoul  from other city
# 23               Seoul  Yeongdeungpo-gu
# 15               Seoul     Seodaemun-gu
# 150   Gyeongsangbuk-do       Yechun-gun
# 3                Seoul     Yangcheon-gu
# 97         Gyeonggi-do  from other city
# 114         Gangwon-do         Wonju-si
# 160   Gyeongsangnam-do         Jinju-si
# 9                Seoul        Gwanak-gu
# 106        Gyeonggi-do  from other city
# 32               Seoul  from other city
# 94         Gyeonggi-do     Uijeongbu-si
# 113         Gangwon-do  from other city
# 40               Busan       Suyeong-gu
# 103        Gyeonggi-do         Suwon-si
# 164   Gyeongsangnam-do       Yangsan-si
# 48               Daegu           Nam-gu
# 145   Gyeongsangbuk-do  from other city
# 158   Gyeongsangnam-do  from other city
# 96         Gyeonggi-do  from other city
# 112         Gangwon-do  from other city
# 80               Ulsan  from other city
# 39               Busan  from other city
# 59             Gwangju  from other city
# 20               Seoul  from other city
# 123  Chungcheongbuk-do  from other city
# 66             Incheon  from other city
# 75             Daejeon  from other city
# 86              Sejong  from other city
# 137       Jeollabuk-do  from other city
# 141       Jeollanam-do  from other city
# 107        Gyeonggi-do  from other city
# 31               Seoul          Jung-gu
# 129  Chungcheongnam-do        Seosan-si
# 76             Daejeon  from other city
# 108        Gyeonggi-do      Seongnam-si
# 11               Seoul     Seongdong-gu
# 26               Seoul        Seocho-gu
# 49               Daegu     Dalseong-gun
# 13               Seoul       Gangnam-gu
# 28               Seoul       Gangnam-gu
# 6                Seoul  from other city
# 98         Gyeonggi-do                -
# 29               Seoul       Gangseo-gu
# 90         Gyeonggi-do      Seongnam-si
# 1                Seoul        Gwanak-gu
# 93         Gyeonggi-do  from other city
# 115         Gangwon-do  from other city
# 130  Chungcheongnam-do  from other city
# 149   Gyeongsangbuk-do  from other city
# 72             Daejeon           Seo-gu
# 33               Seoul                -
# 38               Busan       Dongnae-gu
# 166   Gyeongsangnam-do  from other city
# 84              Sejong           Sejong
# 151   Gyeongsangbuk-do      Chilgok-gun
# 5                Seoul          Guro-gu
# 140       Jeollanam-do         Muan-gun
# 101        Gyeonggi-do         Suwon-si
# 102        Gyeonggi-do        Anyang-si
# 74             Daejeon           Seo-gu
# 16               Seoul        Jongno-gu
# 104        Gyeonggi-do  from other city
# 22               Seoul          Jung-gu
# 14               Seoul          Jung-gu
# 12               Seoul        Jongno-gu
# 42               Busan           Jin-gu
# 0                Seoul       Yongsan-gu
# 92         Gyeonggi-do  from other city
# 63             Incheon  from other city
# 121  Chungcheongbuk-do  from other city
# 43               Busan  from other city
# 53               Daegu  from other city
# 135       Jeollabuk-do  from other city
# 165   Gyeongsangnam-do  from other city
# 173            Jeju-do  from other city
# 50               Daegu           Seo-gu
# 162   Gyeongsangnam-do      Changwon-si
# 41               Busan      Haeundae-gu
# 148   Gyeongsangbuk-do     Gyeongsan-si
# 152   Gyeongsangbuk-do     Gyeongsan-si
# 153   Gyeongsangbuk-do     Gyeongsan-si
# 58             Gwangju          Dong-gu
# 2                Seoul          Guro-gu
# 95         Gyeonggi-do  from other city
# 65             Incheon  from other city
# 122  Chungcheongbuk-do  from other city
# 21               Seoul  from other city
# 154   Gyeongsangbuk-do          Gumi-si
# 120  Chungcheongbuk-do       Goesan-gun
# 19               Seoul     Geumcheon-gu
# 105        Gyeonggi-do  from other city
# 116         Gangwon-do  from other city
# 161   Gyeongsangnam-do     Geochang-gun
# 159   Gyeongsangnam-do     Geochang-gun
# 17               Seoul       Gangnam-gu
# 24               Seoul       Gangnam-gu
# 52               Daegu          Dong-gu
# 131  Chungcheongnam-do  from other city
# 10               Seoul     Eunpyeong-gu
# 71             Daejeon           Seo-gu
# 73             Daejeon           Seo-gu
# 70             Daejeon                -
# 128  Chungcheongnam-do  from other city
# 136       Jeollabuk-do  from other city
# 7                Seoul    Dongdaemun-gu
# 4                Seoul        Dobong-gu
# 34               Seoul          Guro-gu
# 51               Daegu     Dalseong-gun
# 18               Seoul  from other city
# 91         Gyeonggi-do       Bucheon-si
# 64             Incheon  from other city
# 8                Seoul  from other city
# 146   Gyeongsangbuk-do     Cheongdo-gun
# 54               Daegu  from other city
# 44               Busan  from other city
# 163   Gyeongsangnam-do  Changnyeong-gun
# 99         Gyeonggi-do      Seongnam-si
# 147   Gyeongsangbuk-do      Bonghwa-gun
# 25               Seoul     Yangcheon-gu
# 100        Gyeonggi-do        Anyang-si
# 27               Seoul  from other city
#
#                                           Location  Confirmed  Group
# 109                                overseas inflow        305  False
# 35                                 overseas inflow        298  False
# 67                                 overseas inflow         68  False
# 55                                 overseas inflow         41  False
# 45                                 overseas inflow         36  False
# 167                                overseas inflow         26  False
# 81                                 overseas inflow         25  False
# 60                                 overseas inflow         23  False
# 155                                overseas inflow         22  False
# 117                                overseas inflow         16  False
# 132                                overseas inflow         16  False
# 77                                 overseas inflow         15  False
# 142                                overseas inflow         14  False
# 170                                overseas inflow         14  False
# 124                                overseas inflow         13  False
# 138                                overseas inflow         12  False
# 87                                 overseas inflow          5  False
# 85                          gym facility in Sejong          8   True
# 127                        gym facility in Cheonan        103   True
# 57                                             etc        747  False
# 157                                            etc        133  False
# 37                                             etc        100  False
# 111                                            etc         84  False
# 47                                             etc         30  False
# 169                                            etc         20  False
# 79                                             etc         15  False
# 134                                            etc         12  False
# 69                                             etc         11  False
# 126                                            etc         11  False
# 83                                             etc          7  False
# 119                                            etc          7  False
# 139                                            etc          5  False
# 144                                            etc          4  False
# 172                                            etc          4  False
# 62                                             etc          1  False
# 89                                             etc          1  False
# 56                            contact with patient        917  False
# 156                           contact with patient        190  False
# 36                            contact with patient        162  False
# 110                           contact with patient         63  False
# 46                            contact with patient         19  False
# 78                            contact with patient         15  False
# 125                           contact with patient          8  False
# 68                            contact with patient          6  False
# 168                           contact with patient          6  False
# 61                            contact with patient          5  False
# 143                           contact with patient          4  False
# 82                            contact with patient          3  False
# 88                            contact with patient          3  False
# 133                           contact with patient          2  False
# 118                           contact with patient          0  False
# 171                           contact with patient          0  False
# 30                                 Yongin Brothers          4   True
# 23                 Yeongdeungpo Learning Institute          3   True
# 15                              Yeonana News Class          5   True
# 150                                     Yechun-gun         40   True
# 3                      Yangcheon Table Tennis Club         43   True
# 97                     Yangcheon Table Tennis Club         28   True
# 114                            Wonju-si Apartments          4   True
# 160                                    Wings Tower          9   True
# 9                                  Wangsung Church         30   True
# 106                                Wangsung Church          6   True
# 32                         Uiwang Logistics Center          2   True
# 94                   Uijeongbu St. Mary’s Hospital         50   True
# 113                  Uijeongbu St. Mary’s Hospital         10   True
# 40                         Suyeong-gu Kindergarten          5   True
# 103                 Suwon Saeng Myeong Saem Church         10   True
# 164                                    Soso Seowon          3   True
# 48                              Shincheonji Church       4511   True
# 145                             Shincheonji Church        566   True
# 158                             Shincheonji Church         32   True
# 96                              Shincheonji Church         29   True
# 112                             Shincheonji Church         17   True
# 80                              Shincheonji Church         16   True
# 39                              Shincheonji Church         12   True
# 59                              Shincheonji Church          9   True
# 20                              Shincheonji Church          8   True
# 123                             Shincheonji Church          6   True
# 66                              Shincheonji Church          2   True
# 75                              Shincheonji Church          2   True
# 86                              Shincheonji Church          1   True
# 137                             Shincheonji Church          1   True
# 141                             Shincheonji Church          1   True
# 107          Seoul City Hall Station safety worker          5   True
# 31           Seoul City Hall Station safety worker          3   True
# 129                           Seosan-si Laboratory          9   True
# 76                            Seosan-si Laboratory          2   True
# 108                   Seongnam neighbors gathering          5   True
# 11                                Seongdong-gu APT         13   True
# 26                                   Seocho Family          5   True
# 49                           Second Mi-Ju Hospital        196   True
# 13                          Samsung Medical Center          7   True
# 28                 Samsung Fire & Marine Insurance          4   True
# 6                 SMR Newly Planted Churches Group         36   True
# 98                SMR Newly Planted Churches Group         25   True
# 29                       SJ Investment Call Center          0   True
# 90                 River of Grace Community Church         67   True
# 1                                          Richway        119   True
# 93                                         Richway         58   True
# 115                                        Richway          4   True
# 130                                        Richway          3   True
# 149                           Pilgrimage to Israel         41   True
# 72                                     Orange Town          7   True
# 33                                     Orange Life          1   True
# 38                                   Onchun Church         39   True
# 166                                  Onchun Church          2   True
# 84                Ministry of Oceans and Fisheries         31   True
# 151                                  Milal Shelter         36   True
# 5                            Manmin Central Church         41   True
# 140                          Manmin Central Church          2   True
# 101           Lotte Confectionery logistics center         15   True
# 102                              Lord Glory Church         17   True
# 74                 Korea Forest Engineer Institute          3   True
# 16                  Korea Campus Crusade of Christ          7   True
# 104                 Korea Campus Crusade of Christ          7   True
# 22                               KB Life Insurance         13   True
# 14                         Jung-gu Fashion Company          7   True
# 12                         Jongno Community Center         10   True
# 42                                  Jin-gu Academy          4   True
# 0                                    Itaewon Clubs        139   True
# 92                                   Itaewon Clubs         59   True
# 63                                   Itaewon Clubs         53   True
# 121                                  Itaewon Clubs          9   True
# 43                                   Itaewon Clubs          4   True
# 53                                   Itaewon Clubs          2   True
# 135                                  Itaewon Clubs          2   True
# 165                                  Itaewon Clubs          2   True
# 173                                  Itaewon Clubs          1   True
# 50                 Hansarang Convalescent Hospital        124   True
# 162                     Hanmaeum Changwon Hospital          7   True
# 41                     Haeundae-gu Catholic Church          6   True
# 148                  Gyeongsan Seorin Nursing Home         66   True
# 152                     Gyeongsan Jeil Silver Town         17   True
# 153          Gyeongsan Cham Joeun Community Center         16   True
# 58                              Gwangneuksa Temple          5   True
# 2                              Guro-gu Call Center         95   True
# 95                             Guro-gu Call Center         50   True
# 65                             Guro-gu Call Center         20   True
# 122                            Guro-gu Call Center          2   True
# 21                       Guri Collective Infection          5   True
# 154                               Gumi Elim Church         10   True
# 120                      Goesan-gun Jangyeon-myeon         11   True
# 19   Geumcheon-gu rice milling machine manufacture          6   True
# 105  Geumcheon-gu rice milling machine manufacture          6   True
# 116  Geumcheon-gu rice milling machine manufacture          4   True
# 161                   Geochang-gun Woongyang-myeon          8   True
# 159                                Geochang Church         10   True
# 17                  Gangnam Yeoksam-dong gathering          6   True
# 24                           Gangnam Dongin Church          1   True
# 52                                 Fatima Hospital         39   True
# 131              Eunpyeong-Boksagol culture center          3   True
# 10                   Eunpyeong St. Mary's Hospital         14   True
# 71                         Dunsan Electronics Town         13   True
# 73                                 Dreaming Church          4   True
# 70                   Door-to-door sales in Daejeon         55   True
# 128                  Door-to-door sales in Daejeon         10   True
# 136                  Door-to-door sales in Daejeon          3   True
# 7                                    Dongan Church         17   True
# 4                                  Day Care Center         43   True
# 34                                 Daezayeon Korea          3   True
# 51                    Daesil Convalescent Hospital        101   True
# 18                      Daejeon door-to-door sales          1   True
# 91                        Coupang Logistics Center         67   True
# 64                        Coupang Logistics Center         42   True
# 8                         Coupang Logistics Center         25   True
# 146                       Cheongdo Daenam Hospital        119   True
# 54                        Cheongdo Daenam Hospital          2   True
# 44                        Cheongdo Daenam Hospital          1   True
# 163                       Changnyeong Coin Karaoke          7   True
# 99                        Bundang Jesaeng Hospital         22   True
# 147                    Bonghwa Pureun Nursing Home         68   True
# 25                 Biblical Language study meeting          3   True
# 100                     Anyang Gunpo Pastors Group         22   True
# 27                      Anyang Gunpo Pastors Group          1   True

# %%
groupby_province = province[['Province', 'Confirmed', 'Deceased']].groupby(['Province']).sum()

# %%
groupby_province["Percentage"] = (
    groupby_province["Deceased"] / groupby_province["Confirmed"]
) * 100
groupby_province['Percentage'] = groupby_province['Percentage'].apply('{:,.2f}'.format).astype('float64')
groupby_province.sort_values('Percentage', ascending = False)
# Out:
#                    Confirmed  Deceased  Percentage
# Province
# Gangwon-do              5908       225        3.81
# Gyeongsangbuk-do      161079      5393        3.35
# Daegu                 807506     17624        2.18
# Gyeonggi-do            81059      1600        1.97
# Busan                  16341       299        1.83
# Ulsan                   5269        91        1.73
# Daejeon                 5217        58        1.11
# Seoul                  81923       298        0.36
# Incheon                16645        16        0.10
# Gwangju                 3359         0        0.00
# Chungcheongnam-do      16780         0        0.00
# Chungcheongbuk-do       5801         0        0.00
# Gyeongsangnam-do       13860         0        0.00
# Jeju-do                 1449         0        0.00
# Jeollabuk-do            2108         0        0.00
# Jeollanam-do            1763         0        0.00
# Sejong                  5111         0        0.00

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Conclusions

# %% [markdown]
# # Recommendations

# %% [markdown]
# # Suggestions for Improvement
